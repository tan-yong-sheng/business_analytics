# %% [markdown]
# ### Data Wrangling Project: Sharks Attack Dataset
#
# #### Instructions
#
# Welcome to the final project of this data wrangling module! In this project, you will get a chance to work through the entire data wrangling workflow while preparing the shark_attacks.csv file for analysis. This dataset contains very dirty data and will require a lot of work! This project is broken down into key steps of the data wrangling process to help guide you along the process. When you are finished, save the wrangled dataset as a final_project.csv file. Submit the final project as a zip folder named final_project.zip. Make sure the zipped folder has both your wrangled dataset and this word document within it. Best of luck!

# %%
import pandas
import numpy

df = pandas.read_csv("shark_attacks.csv")
df.head(3)
# Out:
#     Case Number        Date    Year        Type    Country               Area  \
# 0    2017.06.11  2017-06-11  2017.0  Unprovoked  AUSTRALIA  Western Australia
# 1  2017.06.10.b  2017-06-10  2017.0  Unprovoked  AUSTRALIA           Victoria
# 2  2017.06.10.a  2017-06-10  2017.0  Unprovoked        USA            Florida
#
#                         Location       Activity         Name Sex  ...  \
# 0       Point Casuarina, Bunbury  Body boarding    Paul Goff   M  ...
# 1  Flinders, Mornington Penisula        Surfing       female   F  ...
# 2    Ponce Inlet, Volusia County        Surfing  Bryan Brock   M  ...
#
#   Fatal (Y/N)   Time           Species                 Investigator or Source  \
# 0           N  08h30  White shark, 4 m                    WA Today, 6/11/2017
# 1           N  15h45      7 gill shark                                    NaN
# 2           N  10h00               NaN  Daytona Beach News-Journal, 6/10/2017
#
#                          pdf  \
# 0        2017.06.11-Goff.pdf
# 1  2017.06.10.b-Flinders.pdf
# 2     2017.06.10.a-Brock.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2017.06.11
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.06.10.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.06.10.a
#
#   Case Number.2 original order
# 0    2017.06.11           6095
# 1  2017.06.10.b           6094
# 2  2017.06.10.a           6093
#
# [3 rows x 22 columns]

# %% [markdown]
# #### Step 2: Data Inspection & Step 3: Data Cleaning
#
# Inspect the dataset. In the box below, discuss the following:
# 1. Are there any irrelevant columns? Which ones?
# 2. Are there any duplicates?
# 3. Which columns have missing data?
# 4. For each column with missing data, describe what you think the best way to handle that missing data is, and why?
# 5. Are there any errors? Describe any you find.
# 6. Is there anything else that requires data cleaning attention?
# (12 marks)

# %% [markdown]
# --------------

# %% [markdown]
# 1. are there any irrelevant columns? Which ones?

# %%
##  inspect data columns
df.columns
# Ans: Case Number, Year, Investigator or Source, pdf, href formula, href, 
#      Case Number.1, Case Number.2
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='object')

# %%
# remove irrelevant columns
df1 = df.drop(columns=["Case Number","Year","Name", "Investigator or Source", "pdf",
                "Injury", "href formula", "href", "Case Number.1", "Case Number.2"])
df1.head(3)
# Out:
#          Date        Type    Country               Area  \
# 0  2017-06-11  Unprovoked  AUSTRALIA  Western Australia
# 1  2017-06-10  Unprovoked  AUSTRALIA           Victoria
# 2  2017-06-10  Unprovoked        USA            Florida
#
#                         Location       Activity Sex  Age Fatal (Y/N)   Time  \
# 0       Point Casuarina, Bunbury  Body boarding   M   48           N  08h30
# 1  Flinders, Mornington Penisula        Surfing   F  NaN           N  15h45
# 2    Ponce Inlet, Volusia County        Surfing   M   19           N  10h00
#
#             Species  original order
# 0  White shark, 4 m            6095
# 1      7 gill shark            6094
# 2               NaN            6093

# %% [markdown]
# 2. Are there any duplicates?

# %%
df1[df1.duplicated()]
# Out:
#            Date        Type       Country                   Area  \
# 662  2012-04-03  Unprovoked           USA                 Hawaii
# 958  2009-08-29  Unprovoked  SOUTH AFRICA  Western Cape Province
#
#                              Location Activity Sex Age Fatal (Y/N)   Time  \
# 662  Leftovers near Chun's Reef, Oahu  Surfing   M  28           N  12h38
# 958                          Glentana  Surfing   M  25           Y  15h30
#
#                 Species  original order
# 662  Tiger shark, 10'              5434
# 958         White shark            5139

# %%
# check and remove duplicated rows
print(f"{df1.duplicated().sum()} rows duplicated...")

# drop duplicated rows if any
print("duplicated rows are removed")
df1.drop_duplicates(inplace=True)
# Out:
# 2 rows duplicated...
# duplicated rows are removed

# %% [markdown]
# 3. Which columns have missing data?

# %%
missing_col = pandas.DataFrame([df1.isna().sum(), df1.isna().sum() 
                                /df1.shape[0]], index=["Missing","Missing (%)"]).T
missing_col["Missing (%)"]= missing_col["Missing (%)"].round(4)
missing_col

# Ans: Year, Type, Country, Area, Location, Activity, Name, 
#      Sex, Agge, Injury, Fatal (Y/N), Time, Species
# Out:
#                 Missing  Missing (%)
# Date                0.0       0.0000
# Type                2.0       0.0017
# Country             1.0       0.0009
# Area               56.0       0.0484
# Location           59.0       0.0510
# Activity           52.0       0.0449
# Sex                43.0       0.0372
# Age               289.0       0.2498
# Fatal (Y/N)         7.0       0.0061
# Time              328.0       0.2835
# Species           447.0       0.3863
# original order      0.0       0.0000

# %% [markdown]
# 4. For each column with missing data, describe what you think the best way to handle that missing data is, and why?

# %%
df2 = df1.copy(deep=True)

# %%
missing_col = pandas.DataFrame([df1.isna().sum(), df1.isna().sum() 
                                /df1.shape[0]], index=["Missing","Missing (%)"]).T
missing_col["Missing (%)"]= missing_col["Missing (%)"].round(4)
missing_col
# Out:
#                 Missing  Missing (%)
# Date                0.0       0.0000
# Type                2.0       0.0017
# Country             1.0       0.0009
# Area               56.0       0.0484
# Location           59.0       0.0510
# Activity           52.0       0.0449
# Sex                43.0       0.0372
# Age               289.0       0.2498
# Fatal (Y/N)         7.0       0.0061
# Time              328.0       0.2835
# Species           447.0       0.3863
# original order      0.0       0.0000

# %%
# filter out the columns with missing values larger than 15%
missing_col[missing_col["Missing (%)"] > 0.15]
# Out:
#          Missing  Missing (%)
# Age        289.0       0.2498
# Time       328.0       0.2835
# Species    447.0       0.3863

# %%
# replace null values with "Unknown" or "Other" value
print("Missing values of columns was filled with 'Unknown' or 'Other' value")
df3 = df2.copy(deep=True)
df3["Age"].fillna("Unknown", inplace=True)
df3["Species"] = df3["Species"].replace(numpy.nan, "Other")
df3["Time"] = df3["Time"].replace(numpy.nan, "Unknown")

df3["Type"] = df3["Type"].replace(numpy.nan, "Unknown")
df3["Sex"] = df3["Sex"].replace(numpy.nan, "Unknown")
df3["Country"] = df3["Country"].replace(numpy.nan, "Other")
df3["Location"] = df3["Location"].replace(numpy.nan, "Other")
df3["Area"] = df3["Area"].replace(numpy.nan, "Other")
df3["Activity"] = df3["Activity"].replace(numpy.nan, "Unknown")

df3["Fatal (Y/N)"] = df3["Fatal (Y/N)"].replace(numpy.nan, "Unknown")
df3["Fatal (Y/N)"] = df3["Fatal (Y/N)"].replace("UNKNOWN", "Unknown")
df3.head(3)
# Out:
# Missing values of columns was filled with 'Unknown' or 'Other' value
#          Date        Type    Country               Area  \
# 0  2017-06-11  Unprovoked  AUSTRALIA  Western Australia
# 1  2017-06-10  Unprovoked  AUSTRALIA           Victoria
# 2  2017-06-10  Unprovoked        USA            Florida
#
#                         Location       Activity Sex      Age Fatal (Y/N)  \
# 0       Point Casuarina, Bunbury  Body boarding   M       48           N
# 1  Flinders, Mornington Penisula        Surfing   F  Unknown           N
# 2    Ponce Inlet, Volusia County        Surfing   M       19           N
#
#     Time           Species  original order
# 0  08h30  White shark, 4 m            6095
# 1  15h45      7 gill shark            6094
# 2  10h00             Other            6093

# %%
# for other columns, drop missing rows as it's smaller number of rows size
print(f"Before dropping missing values, total rows is {df3.shape[0]}")
df3.dropna(inplace=True)

print(f"After dropping missing values, total rows is {df3.shape[0]}")
print("No rows are dropped...")
# Out:
# Before dropping missing values, total rows is 1157
# After dropping missing values, total rows is 1157
# No rows are dropped...

# %% [markdown]
# 5. Are there any errors? Describe any you find.

# %% [markdown]
# (i) Inconsistent date entry

# %%
df4 = df3.copy(deep=True)

# check inconsistent date entry
df4[df4["Date"].str.contains("Reported")]
# Out:
#                        Date        Type           Country             Area  \
# 3      Reported 07-Jun-2017  Unprovoked    UNITED KINGDOM      South Devon
# 10     Reported 06-May-2017    Provoked         AUSTRALIA       Queensland
# 37     Reported 09-Mar-2017  Unprovoked           BAHAMAS      Great Exuma
# 52     Reported 08-Jan-2017     Invalid         AUSTRALIA       Queensland
# 113   Reported  14-Jul-2016  Unprovoked           BAHAMAS            Other
# ...                     ...         ...               ...              ...
# 1133   Reported 19-Apr-2008     Invalid      SOUTH AFRICA    KwaZulu-Natal
# 1137   Reported 09-Apr-2008  Unprovoked              FIJI            Other
# 1139   Reported 08-Apr-2008  Unprovoked               USA          Florida
# 1150   Reported 21-Feb-2008  Unprovoked  FRENCH POLYNESIA  Society Islands
# 1157   Reported 19-Jan-2008     Invalid       NEW ZEALAND     South Island
#
#                                                Location  \
# 3                                         Bantham Beach
# 10                                                Weipa
# 37                                                Other
# 52                                                Other
# 113                                         Tiger Beach
# ...                                                 ...
# 1133                                       Aliwal Shoal
# 1137                                              Other
# 1139  1.4 miles south of Ponce de Leon Jetty, New Sm...
# 1150                                             Tahiti
# 1157                                     Marfells Beach
#
#                          Activity      Sex      Age Fatal (Y/N)     Time  \
# 3                         Surfing        M       30           N  Unknown
# 10    Attempting to lasso a shark        M       29           N  Unknown
# 37                  Washing hands        M       58           N  Unknown
# 52                   Spearfishing        M       35     Unknown  Unknown
# 113                  Scuba Diving        M  Unknown           N  Unknown
# ...                           ...      ...      ...         ...      ...
# 1133                  Free-diving        M  Unknown           N  Unknown
# 1137                 Spearfishing        M  Unknown           N  Unknown
# 1139                      Surfing  Unknown  Unknown           N  Unknown
# 1150                 Spearfishing        M       26           N  Unknown
# 1157                       Wading        M  Unknown           N  Unknown
#
#                                 Species  original order
# 3     3m shark, probably a smooth hound            6092
# 10                             9' shark            6085
# 37                          Lemon shark            6058
# 52                           Bull shark            6043
# 113                     Lemon shark, 9'            5982
# ...                                 ...             ...
# 1133            Tiger shark, 13' female            4964
# 1137                              Other            4960
# 1139                              Other            4958
# 1150                              Other            4947
# 1157               No shark involvement            4940
#
# [64 rows x 12 columns]

# %%
# check inconsistent date entry - continued
## replace "Reported " word in date column
df4["Date"] = df4["Date"].str.replace("Reported ","") 
df4[~ pandas.to_datetime(df4["Date"], errors="coerce").notna()]
# Out:
#                Date        Type         Country            Area  \
# 746    16-Aug--2011  Unprovoked             USA     Puerto Rico
# 749    11-Aug--2011  Unprovoked             USA  North Carolina
# 897     190Feb-2010  Unprovoked     NEW ZEALAND    South Island
# 1101  Late Jul-2008        Boat  UNITED KINGDOM          Sussex
#
#                    Location                     Activity Sex      Age  \
# 746                 Vieques                     Floating   M       27
# 749          Beaufort Inlet                     Swimming   M       54
# 897         Tahunanui Beach                     Swimming   M  Unknown
# 1101  Rock-a-Nore, Hastings  Rowing an inflatable dinghy   M       16
#
#      Fatal (Y/N)     Time                       Species  original order
# 746            N    Night                         Other            5350
# 749            N    14h00                         Other            5347
# 897            N    Night         Possibly a blue shark            5199
# 1101           N  Unknown  Starry smoothhound shark, 1m            4996

# %%
# clean the "Date" column
df4["Date"] = df4["Date"].str.replace("--","-")
df4["Date"] = df4["Date"].str.replace("190Feb-2010","19-Feb-2010")
df4.drop(index=1101, inplace=True) # drop wrong date entry
# check if the inconsistent date format is resolved or not
df4[~ pandas.to_datetime(df4["Date"], errors="coerce").notna()]
# Out:
# Empty DataFrame
# Columns: [Date, Type, Country, Area, Location, Activity, Sex, Age, Fatal (Y/N), Time, Species, original order]
# Index: []

# %%
df4["Date"] = pandas.to_datetime(df4["Date"])
df4["Date"]
# Out:
# 0      2017-06-11
# 1      2017-06-10
# 2      2017-06-10
# 3      2017-06-07
# 4      2017-06-04
#           ...
# 1154   2008-01-30
# 1155   2008-01-29
# 1156   2008-01-27
# 1157   2008-01-19
# 1158   2008-01-14
# Name: Date, Length: 1156, dtype: datetime64[ns]

# %% [markdown]
# (ii) Type error

# %%
# Note: Fatal (Y/N) should only have "Y" and "N" values
df5 = df4.copy(deep=True)
df5["Fatal (Y/N)"].unique()
# Out:
# array(['N', 'Y', 'Unknown', '2017'], dtype=object)

# %%
# filter out rows from df5 where the "Fatal (Y/N)" column contains values other than "Y" , "N" and "Unknown"
df5[~ df5["Fatal (Y/N)"].isin(["Y","N", "Unknown"])]
# Out:
#           Date      Type Country      Area  Location  \
# 646 2012-06-10  Provoked   ITALY  Sardinia  Muravera
#
#                                             Activity Sex Age Fatal (Y/N)  \
# 646  Attempting to rescue an injured & beached shark   M  57        2017
#
#         Time           Species  original order
# 646  Morning  Blue shark, 2.5m            5449

# %%
# Remove rows from df6 where the "Fatal (Y/N)" column contains values other than "Y", "N" and "Unknown"
df6 = df5.drop(index=df5[~ df5["Fatal (Y/N)"].isin(["Y","N", "Unknown"])].index)
print(f"Before excluding rows where Fatal (Y/N) column containing values other than 'Y' and 'N', the shape of dataframe: {df5.shape}")
print(f"After excluding rows where Fatal (Y/N) column containing values other than 'Y' and 'N', the shape of dataframe: {df6.shape}")
# Out:
# Before excluding rows where Fatal (Y/N) column containing values other than 'Y' and 'N', the shape of dataframe: (1156, 12)
# After excluding rows where Fatal (Y/N) column containing values other than 'Y' and 'N', the shape of dataframe: (1155, 12)

# %% [markdown]
# (iii) Clean the age column

# %%
# check what error entries in age column
pandas.DataFrame(df6[~ df6["Age"].str.isdigit() & ~ df6["Age"].isin(["Unknown"])]["Age"].unique(), columns=["Age"])
# Out:
#          Age
# 0        20s
# 1       Teen
# 2        60s
# 3  18 months
# 4        40s
# 5        30s
# 6        50s
# 7       teen
# 8    28 & 26

# %%
# clean the age column
def clean_age_data(age):
    # Replace "s" with an empty string, if present
    ## Example of age data: 40s, 50s
    age = str(age).replace("s","")
    # Check if the age contains an "&" symbol (e.g., "28 & 26")
    if len(age.split("&")) > 1:
        age_list = [float(age) for age in age.split("&")]
        age = str(sum(age_list)/len(age_list))
    # Check if the age ends with "month" (e.g., "18 month")
    if age.endswith("month"):
        age = str(float((age.split(" "))[0])/12)
    # Check if the age is "teen" or "Teen"
    if age in ["teen", "Teen"]:
        # teen is around 13 - 17 years old
        return str((13+17)/2)
    return str(age)

df6["Age"] = df6['Age'].apply(clean_age_data)
df6.head()
# Out:
#         Date        Type         Country               Area  \
# 0 2017-06-11  Unprovoked       AUSTRALIA  Western Australia
# 1 2017-06-10  Unprovoked       AUSTRALIA           Victoria
# 2 2017-06-10  Unprovoked             USA            Florida
# 3 2017-06-07  Unprovoked  UNITED KINGDOM        South Devon
# 4 2017-06-04  Unprovoked             USA            Florida
#
#                                           Location       Activity Sex  \
# 0                         Point Casuarina, Bunbury  Body boarding   M
# 1                    Flinders, Mornington Penisula        Surfing   F
# 2                      Ponce Inlet, Volusia County        Surfing   M
# 3                                    Bantham Beach        Surfing   M
# 4  Middle Sambo Reef off Boca Chica, Monroe County   Spearfishing   M
#
#        Age Fatal (Y/N)     Time                            Species  \
# 0       48           N    08h30                   White shark, 4 m
# 1  Unknown           N    15h45                       7 gill shark
# 2       19           N    10h00                              Other
# 3       30           N  Unknown  3m shark, probably a smooth hound
# 4  Unknown           N  Unknown                           8' shark
#
#    original order
# 0            6095
# 1            6094
# 2            6093
# 3            6092
# 4            6091

# %% [markdown]
# (iv) Clean the Time column

# %%
# check which inconsistent time entries
pandas.DataFrame(df6[~df6["Time"].str.contains("(?:^\d{1,2}h\d{2}|Unknown)", regex=True)]["Time"].unique(), columns=["Time"])
# Out:
#                               Time
# 0             Shortly before 12h00
# 1                          Morning
# 2                        Afternoon
# 3                       After noon
# 4                   Late afternoon
# 5                             1300
# 6                         Midnight
# 7                          Evening
# 8                            Night
# 9   Sometime between 06h00 & 08hoo
# 10                 Early afternoon
# 11                             830
# 12                Just before noon
# 13                            1600
# 14                   Early morning
# 15                            Dawn
# 16                          Midday
# 17                              AM
# 18                            A.M.
# 19                            Dusk
# 20                       Lunchtime
# 21                           15j45
# 22                             500
# 23                    Before 07h00

# %%
df7 = df6.copy(deep=True)
# Replace time values in the "Time" column with a formatted version (e.g., "1200" to "12h00")
df7["Time"] = df7["Time"].str.replace('(\d{1,2})(\d{2})', r'\1h\2', regex=True)
# replace wrong time format like "15j45" into "15h45"
df7["Time"] = df7["Time"].str.replace("(\d{1,2})\w(\d{2})", r"\1h\2", regex=True)
# extract the time from long sentence such as "Shortly before 12h00" and "Before 07h00"
df7["Time"] = df7["Time"].str.extract("(\d{1,2}h\d{2})")
# replace null values with "Unknown" value
df7["Time"] = df7["Time"].fillna("Unknown")
df7["Time"]
# Out:
# 0         08h30
# 1         15h45
# 2         10h00
# 3       Unknown
# 4       Unknown
#          ...
# 1154    Unknown
# 1155    Unknown
# 1156      07h30
# 1157    Unknown
# 1158      14h00
# Name: Time, Length: 1155, dtype: object

# %% [markdown]
# (v) Remove the comma inside "Area" column

# %%
df8 = df7.copy(deep=True)

# %%
# filter out the rows with the comma inside "Area" column
df8[df8["Area"].str.strip().str.endswith(",")]
# Out:
#            Date        Type               Country                    Area  \
# 9    2017-05-12  Unprovoked  UNITED ARAB EMIRATES               Sharjah,
# 1061 2008-10-06  Unprovoked               CROATIA   Split-Dalmatia Count,
#
#                       Location      Activity Sex Age Fatal (Y/N)     Time  \
# 9                  Khor Fakkan  Spearfishing   M  41           N  Unknown
# 1061  Smokvina Bay, Vis Island  Spearfishing   M  43           N    12h00
#
#               Species  original order
# 9               Other            6086
# 1061  5 m white shark            5036

# %%
# remove the comma inside "Area" column
df8["Area"] = df8["Area"].str.strip().str.replace(",$", "", regex=True)
df8.head()
# Out:
#         Date        Type         Country               Area  \
# 0 2017-06-11  Unprovoked       AUSTRALIA  Western Australia
# 1 2017-06-10  Unprovoked       AUSTRALIA           Victoria
# 2 2017-06-10  Unprovoked             USA            Florida
# 3 2017-06-07  Unprovoked  UNITED KINGDOM        South Devon
# 4 2017-06-04  Unprovoked             USA            Florida
#
#                                           Location       Activity Sex  \
# 0                         Point Casuarina, Bunbury  Body boarding   M
# 1                    Flinders, Mornington Penisula        Surfing   F
# 2                      Ponce Inlet, Volusia County        Surfing   M
# 3                                    Bantham Beach        Surfing   M
# 4  Middle Sambo Reef off Boca Chica, Monroe County   Spearfishing   M
#
#        Age Fatal (Y/N)     Time                            Species  \
# 0       48           N    08h30                   White shark, 4 m
# 1  Unknown           N    15h45                       7 gill shark
# 2       19           N    10h00                              Other
# 3       30           N  Unknown  3m shark, probably a smooth hound
# 4  Unknown           N  Unknown                           8' shark
#
#    original order
# 0            6095
# 1            6094
# 2            6093
# 3            6092
# 4            6091

# %% [markdown]
# ## Step 4: Data Cleaning Validation

# %%
# double check the data entries in csv file
df8.to_csv("cross_check_data.csv")

# %%
pandas.DataFrame(df8[~df8["Time"].str.contains("(?:^\d{1,2}h\d{2}|Unknown)", regex=True)]["Time"].unique(), columns=["Time"])
# Out:
# Empty DataFrame
# Columns: [Time]
# Index: []

# %%
# check and validate Age column
pandas.DataFrame(df8[~ df8["Age"].str.isdigit() & df8["Age"].str.isdecimal() & ~ df8["Age"].isin(["Unknown"])]["Age"].unique(), columns=["Age"])
# Out:
# Empty DataFrame
# Columns: [Age]
# Index: []

# %% [markdown]
# ## Step 5: Data Enrichment
#
# With the dataset cleaned it’s time to enrich the data:
# - Make an address column, by combining the Location, Area and Country columns together (this might affect your missing value strategy!).
# - Add a new column, call it “Shark”. Extract information from the Species column. If the species text mentions the word “white”, make the “Shark” column value “Great White”. If the text mentions “bull”, make the “Shark” column value “Bull”. Otherwise, if neither of the words found, make the value “Other”. (Hint: make sure the species column is all lowercase).

# %%
df9 = df8.copy(deep=True)

# %%
# Make an address column, by combining the Location, Area and Country columns together
def combine_address(location, area, country):
    if "Other" in location:
        return "Unknown"
    elif "Other" in area:
        return "Unknown"
    elif "Other" in country:
        return location + ", " + area + ", "
    else:
        return location + ", " + area + ", " + country        

df9["Address"] = df8.apply(lambda x: combine_address(x["Location"], x["Area"], x["Country"]), axis=1)
df9
# Out:
#            Date        Type         Country               Area  \
# 0    2017-06-11  Unprovoked       AUSTRALIA  Western Australia
# 1    2017-06-10  Unprovoked       AUSTRALIA           Victoria
# 2    2017-06-10  Unprovoked             USA            Florida
# 3    2017-06-07  Unprovoked  UNITED KINGDOM        South Devon
# 4    2017-06-04  Unprovoked             USA            Florida
# ...         ...         ...             ...                ...
# 1154 2008-01-30    Provoked           JAPAN          Tokyo Bay
# 1155 2008-01-29  Unprovoked    SOUTH AFRICA      KwaZulu-Natal
# 1156 2008-01-27    Provoked       AUSTRALIA         Queensland
# 1157 2008-01-19     Invalid     NEW ZEALAND       South Island
# 1158 2008-01-14        Boat     NEW ZEALAND       North Island
#
#                                              Location  \
# 0                            Point Casuarina, Bunbury
# 1                       Flinders, Mornington Penisula
# 2                         Ponce Inlet, Volusia County
# 3                                       Bantham Beach
# 4     Middle Sambo Reef off Boca Chica, Monroe County
# ...                                               ...
# 1154                                            Other
# 1155                   Suncoast Pirates Beach, Durban
# 1156                       200 km east of Coolangatta
# 1157                                   Marfells Beach
# 1158                                      Omaha Beach
#
#                                                Activity      Sex      Age  \
# 0                                         Body boarding        M       48
# 1                                               Surfing        F  Unknown
# 2                                               Surfing        M       19
# 3                                               Surfing        M       30
# 4                                          Spearfishing        M  Unknown
# ...                                                 ...      ...      ...
# 1154                                             Diving  Unknown  Unknown
# 1155                                        Surf-skiing        M       42
# 1156  Accidentally stood on hooked shark's tail befo...        M       20
# 1157                                             Wading        M  Unknown
# 1158               Attempting to chase shark out to sea  Unknown  Unknown
#
#      Fatal (Y/N)     Time                            Species  original order  \
# 0              N    08h30                   White shark, 4 m            6095
# 1              N    15h45                       7 gill shark            6094
# 2              N    10h00                              Other            6093
# 3              N  Unknown  3m shark, probably a smooth hound            6092
# 4              N  Unknown                           8' shark            6091
# ...          ...      ...                                ...             ...
# 1154     Unknown  Unknown                 Goblin shark, 4.2'            4943
# 1155           N  Unknown                 Blacktip shark, 2m            4942
# 1156           N    07h30                   Mako shark, 90kg            4941
# 1157           N  Unknown               No shark involvement            4940
# 1158           N    14h00            Bronze whaler shark, 4m            4939
#
#                                                 Address
# 0     Point Casuarina, Bunbury, Western Australia, A...
# 1     Flinders, Mornington Penisula, Victoria, AUSTR...
# 2             Ponce Inlet, Volusia County, Florida, USA
# 3            Bantham Beach, South Devon, UNITED KINGDOM
# 4     Middle Sambo Reef off Boca Chica, Monroe Count...
# ...                                                 ...
# 1154                                            Unknown
# 1155  Suncoast Pirates Beach, Durban, KwaZulu-Natal,...
# 1156  200 km east of Coolangatta, Queensland, AUSTRALIA
# 1157          Marfells Beach, South Island, NEW ZEALAND
# 1158             Omaha Beach, North Island, NEW ZEALAND
#
# [1155 rows x 13 columns]

# %%
# Add a new column, call it “Shark”. Extract information from the Species column. If the species text mentions the word “white”, 
# make the “Shark” column value “Great White”. If the text mentions “bull”, make the “Shark” column value “Bull”. 
# Otherwise, if neither of the words found, make the value “Other”. 

def categorize_species(x):
    if "white" in x.lower():
        return "Great White"
    elif "bull" in x.lower():
        return "Bull"
    else:
        return "Other"

df9["Species"] = df8["Species"].apply(categorize_species)
df9
# Out:
#            Date        Type         Country               Area  \
# 0    2017-06-11  Unprovoked       AUSTRALIA  Western Australia
# 1    2017-06-10  Unprovoked       AUSTRALIA           Victoria
# 2    2017-06-10  Unprovoked             USA            Florida
# 3    2017-06-07  Unprovoked  UNITED KINGDOM        South Devon
# 4    2017-06-04  Unprovoked             USA            Florida
# ...         ...         ...             ...                ...
# 1154 2008-01-30    Provoked           JAPAN          Tokyo Bay
# 1155 2008-01-29  Unprovoked    SOUTH AFRICA      KwaZulu-Natal
# 1156 2008-01-27    Provoked       AUSTRALIA         Queensland
# 1157 2008-01-19     Invalid     NEW ZEALAND       South Island
# 1158 2008-01-14        Boat     NEW ZEALAND       North Island
#
#                                              Location  \
# 0                            Point Casuarina, Bunbury
# 1                       Flinders, Mornington Penisula
# 2                         Ponce Inlet, Volusia County
# 3                                       Bantham Beach
# 4     Middle Sambo Reef off Boca Chica, Monroe County
# ...                                               ...
# 1154                                            Other
# 1155                   Suncoast Pirates Beach, Durban
# 1156                       200 km east of Coolangatta
# 1157                                   Marfells Beach
# 1158                                      Omaha Beach
#
#                                                Activity      Sex      Age  \
# 0                                         Body boarding        M       48
# 1                                               Surfing        F  Unknown
# 2                                               Surfing        M       19
# 3                                               Surfing        M       30
# 4                                          Spearfishing        M  Unknown
# ...                                                 ...      ...      ...
# 1154                                             Diving  Unknown  Unknown
# 1155                                        Surf-skiing        M       42
# 1156  Accidentally stood on hooked shark's tail befo...        M       20
# 1157                                             Wading        M  Unknown
# 1158               Attempting to chase shark out to sea  Unknown  Unknown
#
#      Fatal (Y/N)     Time      Species  original order  \
# 0              N    08h30  Great White            6095
# 1              N    15h45        Other            6094
# 2              N    10h00        Other            6093
# 3              N  Unknown        Other            6092
# 4              N  Unknown        Other            6091
# ...          ...      ...          ...             ...
# 1154     Unknown  Unknown        Other            4943
# 1155           N  Unknown        Other            4942
# 1156           N    07h30        Other            4941
# 1157           N  Unknown        Other            4940
# 1158           N    14h00        Other            4939
#
#                                                 Address
# 0     Point Casuarina, Bunbury, Western Australia, A...
# 1     Flinders, Mornington Penisula, Victoria, AUSTR...
# 2             Ponce Inlet, Volusia County, Florida, USA
# 3            Bantham Beach, South Devon, UNITED KINGDOM
# 4     Middle Sambo Reef off Boca Chica, Monroe Count...
# ...                                                 ...
# 1154                                            Unknown
# 1155  Suncoast Pirates Beach, Durban, KwaZulu-Natal,...
# 1156  200 km east of Coolangatta, Queensland, AUSTRALIA
# 1157          Marfells Beach, South Island, NEW ZEALAND
# 1158             Omaha Beach, North Island, NEW ZEALAND
#
# [1155 rows x 13 columns]

# %%
df9.to_csv("final_project.csv")
